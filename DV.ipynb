# %%
# !pip install seaborn
# !pip install pandas

# %%
import seaborn as sns
import pandas as pd
data = pd.read_csv("C:/Users/thani/Downloads/archive (1)/DataScience_salaries_2024.csv",encoding='latin1')
data
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# ...

# %%
sns.countplot(data=data, x="job_title")
# Out:
# <Axes: xlabel='job_title', ylabel='count'>

# %%
sns.histplot(data=data, x="job_title")
# Out:
# <Axes: xlabel='job_title', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(11,6))
jobtitle=data['job_title']
salarycurrency=data['salary_currency']
plt.bar(jobtitle,salarycurrency,color='Blue',width = 0.5)
plt.xlabel("job title")
plt.ylabel("salary currency")
# Out:
# Text(0, 0.5, 'salary currency')
